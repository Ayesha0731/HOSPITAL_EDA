# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha0731/HOSPITAL_EDA/blob/main/HOSPITAL_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from wordcloud import WordCloud

# %%
data=pd.read_csv("https://raw.githubusercontent.com/mGalarnyk/datasciencecoursera/refs/heads/master/2_R_Programming/data/hospital-data.csv")

# %%
data
# Out:
#      Provider Number                           Hospital Name  \
# 0             010001        SOUTHEAST ALABAMA MEDICAL CENTER
# 1             010005           MARSHALL MEDICAL CENTER SOUTH
# 2             010006          ELIZA COFFEE MEMORIAL HOSPITAL
# 3             010007                MIZELL MEMORIAL HOSPITAL
# 4             010008             CRENSHAW COMMUNITY HOSPITAL
# ...              ...                                     ...
# 4821          670072        WESTBURY COMMUNITY HOSPITAL, LLC
# 4822          670073          METHODIST HOSPITAL FOR SURGERY
# 4823          670075  ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
# 4824          670076         HERITAGE PARK SURGICAL HOSPITAL
# 4825          670077         METHODIST WEST HOUSTON HOSPITAL
#
#                        Address 1  Address 2  Address 3      City State  \
# 0         1108 ROSS CLARK CIRCLE        NaN        NaN    DOTHAN    AL
# 1     2505 U S HIGHWAY 431 NORTH        NaN        NaN      BOAZ    AL
# ...

# %%
data.head()
# Out:
#   Provider Number                     Hospital Name  \
# 0          010001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010005     MARSHALL MEDICAL CENTER SOUTH
# 2          010006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3          010007          MIZELL MEMORIAL HOSPITAL
# 4          010008       CRENSHAW COMMUNITY HOSPITAL
#
#                     Address 1  Address 2  Address 3      City State  ZIP Code  \
# 0      1108 ROSS CLARK CIRCLE        NaN        NaN    DOTHAN    AL     36301
# 1  2505 U S HIGHWAY 431 NORTH        NaN        NaN      BOAZ    AL     35957
# 2          205 MARENGO STREET        NaN        NaN  FLORENCE    AL     35631
# 3               702 N MAIN ST        NaN        NaN       OPP    AL     36467
# 4         101 HOSPITAL CIRCLE        NaN        NaN   LUVERNE    AL     36049
#
#        County  Phone Number         Hospital Type  \
# 0     HOUSTON    3347938701  Acute Care Hospitals
# 1    MARSHALL    2565938310  Acute Care Hospitals
# ...

# %%
data.tail()
# Out:
#      Provider Number                           Hospital Name  \
# 4821          670072        WESTBURY COMMUNITY HOSPITAL, LLC
# 4822          670073          METHODIST HOSPITAL FOR SURGERY
# 4823          670075  ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
# 4824          670076         HERITAGE PARK SURGICAL HOSPITAL
# 4825          670077         METHODIST WEST HOUSTON HOSPITAL
#
#                        Address 1  Address 2  Address 3     City State  \
# 4821                 5556 GASMER        NaN        NaN  HOUSTON    TX
# 4822        17101 DALLAS PARKWAY        NaN        NaN  ADDISON    TX
# 4823  20171 CHASEWOOD PARK DRIVE        NaN        NaN  HOUSTON    TX
# 4824           3601 CALAIS DRIVE        NaN        NaN  SHERMAN    TX
# 4825          18500 KATY FREEWAY        NaN        NaN  HOUSTON    TX
#
#       ZIP Code   County  Phone Number         Hospital Type  \
# 4821     77035   HARRIS    7134222650  Acute Care Hospitals
# ...

# %%
data.shape
# Out:
# (4826, 13)

# %%
data.City.unique()
# Out:
# array(['DOTHAN', 'BOAZ', 'FLORENCE', ..., 'MC KINNEY', 'FLOWER MOUND',
#        'ADDISON'], dtype=object)

# %%
 data.City.nunique()
# Out:
# 3018

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4826 entries, 0 to 4825
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Provider Number     4826 non-null   object
#  1   Hospital Name       4826 non-null   object
#  2   Address 1           4826 non-null   object
#  3   Address 2           0 non-null      float64
#  4   Address 3           0 non-null      float64
#  5   City                4826 non-null   object
#  6   State               4826 non-null   object
#  7   ZIP Code            4826 non-null   int64
#  8   County              4805 non-null   object
#  9   Phone Number        4826 non-null   int64
#  10  Hospital Type       4826 non-null   object
#  11  Hospital Ownership  4826 non-null   object
#  12  Emergency Services  4826 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 490.3+ KB

# %%
data.describe()
# Out:
#        Address 2  Address 3      ZIP Code  Phone Number
# count        0.0        0.0   4826.000000  4.826000e+03
# mean         NaN        NaN  53079.289888  5.829414e+09
# std          NaN        NaN  27002.162551  2.333778e+09
# min          NaN        NaN    603.000000  9.369338e+08
# 25%          NaN        NaN  32207.500000  3.616118e+09
# 50%          NaN        NaN  54153.500000  6.033435e+09
# 75%          NaN        NaN  75225.500000  7.877054e+09
# max          NaN        NaN  99929.000000  9.898943e+09

# %%
data.drop_duplicates(['Provider Number'],keep = 'first', inplace = True)

# %%
data.shape
# Out:
# (4826, 13)

# %%
data.isnull()
# Out:
#       Provider Number  Hospital Name  Address 1  Address 2  Address 3   City  \
# 0               False          False      False       True       True  False
# 1               False          False      False       True       True  False
# 2               False          False      False       True       True  False
# 3               False          False      False       True       True  False
# 4               False          False      False       True       True  False
# ...               ...            ...        ...        ...        ...    ...
# 4821            False          False      False       True       True  False
# 4822            False          False      False       True       True  False
# 4823            False          False      False       True       True  False
# 4824            False          False      False       True       True  False
# 4825            False          False      False       True       True  False
#
# ...

# %%
data.isnull().sum()
# Out:
# Provider Number          0
# Hospital Name            0
# Address 1                0
# Address 2             4826
# Address 3             4826
# City                     0
# State                    0
# ZIP Code                 0
# County                  21
# Phone Number             0
# Hospital Type            0
# Hospital Ownership       0
# Emergency Services       0
# dtype: int64

# %%
data['Hospital Name']
# Out:
# 0             SOUTHEAST ALABAMA MEDICAL CENTER
# 1                MARSHALL MEDICAL CENTER SOUTH
# 2               ELIZA COFFEE MEMORIAL HOSPITAL
# 3                     MIZELL MEMORIAL HOSPITAL
# 4                  CRENSHAW COMMUNITY HOSPITAL
#                          ...
# 4821          WESTBURY COMMUNITY HOSPITAL, LLC
# 4822            METHODIST HOSPITAL FOR SURGERY
# 4823    ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
# 4824           HERITAGE PARK SURGICAL HOSPITAL
# 4825           METHODIST WEST HOUSTON HOSPITAL
# Name: Hospital Name, Length: 4826, dtype: object

# %%
data['Hospital Name'].unique()
# Out:
# array(['SOUTHEAST ALABAMA MEDICAL CENTER',
#        'MARSHALL MEDICAL CENTER SOUTH', 'ELIZA COFFEE MEMORIAL HOSPITAL',
#        ..., "ST LUKE'S HOSPITAL AT THE VINTAGE, LLC",
#        'HERITAGE PARK SURGICAL HOSPITAL',
#        'METHODIST WEST HOUSTON HOSPITAL'], dtype=object)

# %%
data['Hospital Name'].nunique()
# Out:
# 4624

# %%
print(data['Hospital Name'].unique()[0])
# Out:
# SOUTHEAST ALABAMA MEDICAL CENTER

# %%
print(data['Hospital Name'].unique()[21])
# Out:
# UNIVERSITY OF ALABAMA HOSPITAL

# %%
data['Hospital Name'] = data['Hospital Name'].apply(lambda x:x[2:-2])
print(data['Hospital Name'].unique())
# Out:
# ['UTHEAST ALABAMA MEDICAL CENT' 'RSHALL MEDICAL CENTER SOU'
#  'IZA COFFEE MEMORIAL HOSPIT' ... " LUKE'S HOSPITAL AT THE VINTAGE, L"
#  'RITAGE PARK SURGICAL HOSPIT' 'THODIST WEST HOUSTON HOSPIT']

# %%
data['Hospital Name'] = data['Hospital Name'].apply(lambda x: np.where(x == "","NA",x))
print(data['Hospital Name'].unique())
# Out:
# ['UTHEAST ALABAMA MEDICAL CENT' 'RSHALL MEDICAL CENTER SOU'
#  'IZA COFFEE MEMORIAL HOSPIT' ... " LUKE'S HOSPITAL AT THE VINTAGE, L"
#  'RITAGE PARK SURGICAL HOSPIT' 'THODIST WEST HOUSTON HOSPIT']

# %%
data['City'].unique()
# Out:
# array(['DOTHAN', 'BOAZ', 'FLORENCE', ..., 'MC KINNEY', 'FLOWER MOUND',
#        'ADDISON'], dtype=object)

# %%
len(data['City'].unique())
# Out:
# 3018

# %%
data['State'].head()
# Out:
# 0    AL
# 1    AL
# 2    AL
# 3    AL
# 4    AL
# Name: State, dtype: object

# %%
data['State'].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN',
#        'TX', 'UT', 'VT', 'VI', 'VA', 'WA', 'WV', 'WI', 'WY', 'AS', 'GU',
#        'MP'], dtype=object)

# %%
data['State'].nunique()
# Out:
# 56

# %%
data['County'].unique()
# Out:
# array(['HOUSTON', 'MARSHALL', 'LAUDERDALE', ..., 'AMERICAN SAMOA', 'GUAM',
#        'ROCKWALL'], dtype=object)

# %%
outlets = data['City'].value_counts()

# %%
outlets
# Out:
# City
# CHICAGO                           27
# HOUSTON                           26
# LOS ANGELES                       21
# DALLAS                            19
# WASHINGTON                        17
#                                   ..
# SHERIDAN                           1
# BASIN                              1
# NEWCASTLE                          1
# THERMOPOLIS                        1
# WHEATLAND                          1
# Name: count, Length: 3018, dtype: int64

# %%
chains = outlets[outlets >= 2]
single  = outlets[outlets == 1]

# %%
single
# Out:
# City
# ALABASTER                         1
# OPP                               1
# HARTSELLE                         1
# GUNTERSVILLE                      1
# FORT PAYNE                        1
#                                  ..
# SHERIDAN                          1
# BASIN                             1
# NEWCASTLE                         1
# THERMOPOLIS                       1
# WHEATLAND                         1
# Name: count, Length: 2296, dtype: int64

# %%
chains
# Out:
# City
# CHICAGO        27
# HOUSTON        26
# LOS ANGELES    21
# DALLAS         19
# WASHINGTON     17
#                ..
# FORSYTH         2
# BREMEN          2
# ANNISTON        2
# COMMERCE        2
# WAUKEGAN        2
# Name: count, Length: 722, dtype: int64

# %%
data.shape
# Out:
# (4826, 13)

# %%
chains.shape
# Out:
# (722,)

# %%
single.shape
# Out:
# (2296,)

# %%
print("total hospitals in our data = ", data.shape[0])

print("total hospitals that are part of some chain = ", data.shape[0] - single.shape[0])

print("percentage of hospitals that are part of some chain = ", np.round((data.shape[0] - single.shape[0]) / data.shape[0],2)*100, "%")
# Out:
# total hospitals in our data =  4826
# total hospitals that are part of some chain =  2530
# percentage of hospitals that are part of some chain =  52.0 %

# %%
chains.head()
# Out:
# City
# CHICAGO        27
# HOUSTON        26
# LOS ANGELES    21
# DALLAS         19
# WASHINGTON     17
# Name: count, dtype: int64

# %%
top10_foodchains = data['City'].value_counts()[:10].sort_values(ascending = True)

# %%
top10_foodchains
# Out:
# City
# SPRINGFIELD      16
# OKLAHOMA CITY    16
# COLUMBUS         16
# JACKSON          17
# WASHINGTON       17
# PHILADELPHIA     17
# DALLAS           19
# LOS ANGELES      21
# HOUSTON          26
# CHICAGO          27
# Name: count, dtype: int64

# %%
height = top10_foodchains.values
bars = top10_foodchains.index
y_pos = np.arange(len(bars))

fig = plt.figure(figsize = [11,8], frameon = False)
ax = fig.gca()
ax.spines['top'].set_visible("#424242")
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color("#424242")
ax.spines['bottom'].set_color("#424242")

colors = ['#f9cdac', '#f2a49f', '#ec7c92', '#e65586','#bc438b', '#933291','#692398','#551c7b','#41155e','#2d0f41']

plt.barh(y_pos, height, color = colors)

plt.xticks(color = "#424242")
plt.yticks(y_pos, bars, color = "#424242")
plt.xlabel("Number of outlets in India")

for i, v in enumerate(height):
    plt.text(v + 3, i, str(v), color = 'black', fontweight = 'bold')
plt.title("Top 10 Hospitals chains in India")
plt.show()

# %%
height = top10_foodchains.values
bars = top10_foodchains.index
y_pos = np.arange(len(bars))

fig = plt.figure(figsize=[11,8], frameon=False)
ax = fig.gca()

# Set spine colors
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color("#424242")
ax.spines['bottom'].set_color("#424242")

colors = ['#f9cdac', '#f2a49f', '#ec7c92', '#e65586',
          '#bc438b', '#933291', '#692398', '#551c7b', '#41155e', '#2d0f41']

plt.barh(y_pos, height, color=colors)

plt.xticks(color="#424242")
plt.yticks(y_pos, bars, color="#424242")
plt.xlabel("Number of Outlets in India", fontsize=12, color="#424242")
plt.title("Top 10 Hospitals Chains in India", fontsize=16, color="#424242")

for i, v in enumerate(height):
    plt.text(v + 3, i, str(v), color='black', fontweight='bold')

plt.xlim(0, max(height) + 20)  # Prevent clipping
plt.tight_layout()
plt.show()

# %%
outlets = data['City'].value_counts()

# %%
outlets
# Out:
# City
# CHICAGO                           27
# HOUSTON                           26
# LOS ANGELES                       21
# DALLAS                            19
# WASHINGTON                        17
#                                   ..
# SHERIDAN                           1
# BASIN                              1
# NEWCASTLE                          1
# THERMOPOLIS                        1
# WHEATLAND                          1
# Name: count, Length: 3018, dtype: int64

# %%
Min_outlets = outlets[outlets > 4]

# %%
Min_outlets
# Out:
# City
# CHICAGO        27
# HOUSTON        26
# LOS ANGELES    21
# DALLAS         19
# WASHINGTON     17
#                ..
# CANTON          5
# SUGAR LAND      5
# TYLER           5
# CARTHAGE        5
# PLANO           5
# Name: count, Length: 140, dtype: int64

# %%
data['Hospital Name']
# Out:
# 0             UTHEAST ALABAMA MEDICAL CENT
# 1                RSHALL MEDICAL CENTER SOU
# 2               IZA COFFEE MEMORIAL HOSPIT
# 3                     ZELL MEMORIAL HOSPIT
# 4                  ENSHAW COMMUNITY HOSPIT
#                        ...
# 4821          STBURY COMMUNITY HOSPITAL, L
# 4822            THODIST HOSPITAL FOR SURGE
# 4823     LUKE'S HOSPITAL AT THE VINTAGE, L
# 4824           RITAGE PARK SURGICAL HOSPIT
# 4825           THODIST WEST HOUSTON HOSPIT
# Name: Hospital Name, Length: 4826, dtype: object

# %%
print(data['Address 1'].nunique())
# Out:
# 4800

# %%
plt.figure(figsize=(12, 6)) # Adjust figure size for better readability
sns.countplot(data=data, y='Hospital Ownership', order = data['Hospital Ownership'].value_counts().index, palette='viridis')
plt.title("Distribution of Hospital Ownership")
plt.xlabel("Count")
plt.ylabel("Hospital Ownership Type")
plt.tight_layout() # Adjust layout to prevent labels overlapping
plt.show()
# Out:
# <ipython-input-84-1821504452>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, y='Hospital Ownership', order = data['Hospital Ownership'].value_counts().index, palette='viridis')

# %% [markdown]
# **CONCLUSION:**
#
# The hospital dataset was successfully loaded and cleaned for analysis.
#
# I handled missing and improperly formatted hospital names.
#
# Visualizations revealed:
#
# The distribution of hospital ownership types.
#
# The number of hospitals in different cities.
#
# The number of hospitals in india
#
# The proportion of hospitals that are part of a chain.
#
# These insights provide a clear view of the healthcare structure and ownership trends across regions.
